# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
np.random.seed(100)
print(np.random.rand(3))
# Out:
# [0.54340494 0.27836939 0.42451759]

# %%
customer_id=np.arange(1,101)

# %%
ages=np.random.randint(18,60,100)

# %%
income=np.random.randint(20000, 150000, 100)

# %%
spending_score=np.random.randint(1,101,100)

# %%
orders_per_month=np.random.randint(1,20,100)

# %%
gender=np.random.choice(['Male', 'Female', 'Other'], 100)

# %%
data={
    'customer_id' : customer_id,
    'age' : ages,
    'income' : income,
    'spending_score' : spending_score,
    'orders_per_month' : orders_per_month,
    'gender' : gender
}

# %%
df=pd.DataFrame(data)

# %%
df['Total_Spend_Estimate']=df['income']*df['spending_score']/100

# %%
df['Category']=np.where(
    df['spending_score']>=70,
    'High',
     np.where(df['spending_score']>=40,
    'Medium',
    'Low'
             )
)

# %%
a=df['income'].mean()

# %%
b=df['spending_score'].median()

# %%
c=df['income'].std()

# %%
np.corrcoef(
    df['income'],
    df['spending_score']
)
# Out:
# array([[1.        , 0.08098286],
#        [0.08098286, 1.        ]])

# %%
df.nlargest(5, 'Total_Spend_Estimate')
# Out:
#     customer_id  age  income  spending_score  orders_per_month  gender  \
# 15           16   45  141544             100                 4  Female
# 44           45   26  145313              93                16   Other
# 92           93   57  141655              88                 1    Male
# 19           20   31  144562              82                17  Female
# 54           55   18  140786              83                16  Female
#
#     Total_Spend_Estimate Category
# 15             141544.00     High
# 44             135141.09     High
# 92             124656.40     High
# 19             118540.84     High
# 54             116852.38     High

# %%
df.groupby('gender')['income'].mean()
# Out:
# gender
# Female    94853.914286
# Male      87907.218750
# Other     79075.727273
# Name: income, dtype: float64

# %%
df.groupby('Category')['spending_score'].mean()
# Out:
# Category
# High      86.900000
# Low       22.205882
# Medium    53.638889
# Name: spending_score, dtype: float64

# %%
df
# Out:
#     customer_id  age  income  spending_score  orders_per_month  gender  \
# 0             1   28   20429              54                16   Other
# 1             2   48  135491              18                18   Other
# 2             3   52   86576              66                11   Other
# 3             4   20  115756              43                 9    Male
# 4             5   52   93558              94                 9   Other
# ..          ...  ...     ...             ...               ...     ...
# 95           96   20  108755              93                19   Other
# 96           97   42  124368              53                13   Other
# 97           98   35  143634              45                18    Male
# 98           99   55   83485              14                 2  Female
# 99          100   43   53274              34                 3  Female
#
#     Total_Spend_Estimate Category
# 0               11031.66   Medium
# 1               24388.38      Low
# 2               57140.16   Medium
# 3               49775.08   Medium
# 4               87944.52     High
# ..                   ...      ...
# 95             101142.15     High
# 96              65915.04   Medium
# 97              64635.30   Medium
# 98              11687.90      Low
# 99              18113.16      Low
#
# [100 rows x 8 columns]

# %%
bins=np.arange(20000, 160001, 10000)
plt.figure(figsize=(15,4))
plt.hist(df['income'], edgecolor='black', bins=bins)
plt.xticks(bins)
# Out:
# ([<matplotlib.axis.XTick at 0x1cd788ffd90>,
#   <matplotlib.axis.XTick at 0x1cd78803390>,
#   <matplotlib.axis.XTick at 0x1cd78803b10>,
#   <matplotlib.axis.XTick at 0x1cd78869810>,
#   <matplotlib.axis.XTick at 0x1cd78869f90>,
#   <matplotlib.axis.XTick at 0x1cd7886a710>,
#   <matplotlib.axis.XTick at 0x1cd7886ae90>,
#   <matplotlib.axis.XTick at 0x1cd7886b610>,
#   <matplotlib.axis.XTick at 0x1cd7886bd90>,
#   <matplotlib.axis.XTick at 0x1cd78868050>,
#   <matplotlib.axis.XTick at 0x1cd78868550>,
#   <matplotlib.axis.XTick at 0x1cd78868cd0>,
#   <matplotlib.axis.XTick at 0x1cd7891c690>,
#   <matplotlib.axis.XTick at 0x1cd7891ce10>,
#   <matplotlib.axis.XTick at 0x1cd7891d590>],
#  [Text(20000, 0, '20000'),
#   Text(30000, 0, '30000'),
#   Text(40000, 0, '40000'),
#   Text(50000, 0, '50000'),
#   Text(60000, 0, '60000'),
#   Text(70000, 0, '70000'),
#   Text(80000, 0, '80000'),
#   Text(90000, 0, '90000'),
#   Text(100000, 0, '100000'),
#   Text(110000, 0, '110000'),
#   Text(120000, 0, '120000'),
#   Text(130000, 0, '130000'),
#   Text(140000, 0, '140000'),
#   Text(150000, 0, '150000'),
#   Text(160000, 0, '160000')])

# %%
df.head()
# Out:
#    customer_id  age  income  spending_score  orders_per_month gender  \
# 0            1   28   20429              54                16  Other
# 1            2   48  135491              18                18  Other
# 2            3   52   86576              66                11  Other
# 3            4   20  115756              43                 9   Male
# 4            5   52   93558              94                 9  Other
#
#    Total_Spend_Estimate Category
# 0              11031.66   Medium
# 1              24388.38      Low
# 2              57140.16   Medium
# 3              49775.08   Medium
# 4              87944.52     High

# %%
a=df.groupby('Category')['customer_id'].count()
a
# Out:
# Category
# High      30
# Low       34
# Medium    36
# Name: customer_id, dtype: int64

# %%
plt.pie(a, 
       autopct='%1.1f%%', 
       wedgeprops={
           'edgecolor' : 'black',
           'linestyle' : '--'
       },
       shadow=True
       )
# Out:
# ([<matplotlib.patches.Wedge at 0x1cd795e8190>,
#   <matplotlib.patches.Wedge at 0x1cd795e8550>,
#   <matplotlib.patches.Wedge at 0x1cd795e8a50>],
#  [Text(0.6465637011386807, 0.8899187493079641, ''),
#   Text(-1.080515977997109, 0.20611943453481438, ''),
#   Text(0.46835741088254246, -0.9953096682296427, '')],
#  [Text(0.3526711097120076, 0.48541022689525304, '30.0%'),
#   Text(-0.5893723516347866, 0.1124287824735351, '34.0%'),
#   Text(0.25546767866320497, -0.5428961826707142, '36.0%')])

# %%
plt.figure(figsize=(18,5))
plt.plot(df['customer_id'], df['spending_score'])

# %%
plt.figure(figsize=(10,4))
sns.scatterplot(
    x='income',
    y='spending_score',
    data=df
)
# Out:
# <Axes: xlabel='income', ylabel='spending_score'>
